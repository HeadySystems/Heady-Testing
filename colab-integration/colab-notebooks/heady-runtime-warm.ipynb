# %% [markdown]
# # Heady™ Runtime — WARM Pool
# © 2026 HeadySystems Inc. — Eric Haywood — 51 Provisional Patents
#
# This notebook runs as the **warm** pool Colab Pro+ runtime for the Heady Latent OS.
# Batch processing, fine-tuning, large embedding jobs

# %%
# Install dependencies
# !pip install -q sentence-transformers torch websockets numpy pynvml

# %%
# Configure gateway URL
import os
os.environ['HEADY_GATEWAY_URL'] = 'https://colab-gateway.headysystems.com'
POOL = 'warm'

# %%
# Download and start runtime bridge
# !curl -sL https://raw.githubusercontent.com/HeadyMe/headyos-core/main/colab-integration/colab-runtime-bridge.py -o bridge.py

# Or paste the bridge code directly:
from colab_runtime_bridge import HeadyRuntimeBridge
bridge = HeadyRuntimeBridge(pool='warm')
bridge.start()
